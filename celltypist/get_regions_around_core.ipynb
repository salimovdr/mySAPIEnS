# %%
import pandas as pd
from tqdm import tqdm

# %%
DATA_NAME = "PBMC10k_PBMC"
CORE_GENES_FILE = f"../../Datasets_old/{DATA_NAME}/output/celltypist/celltypist_core_genes.txt"
GTF_FILE = "../../Datasets/gencode.v49.basic.annotation.gtf" 
WINDOW = 1000
OUT_BED = f"../../Datasets_old/{DATA_NAME}/output/celltypist/core_genes_regions_{WINDOW}bp.bed"

# %%
with open(CORE_GENES_FILE) as f:
    core_genes = set(line.strip() for line in f if line.strip())

print(f"Генов в ядре: {len(core_genes)}")
# Out:
# Генов в ядре: 1742

# %%
gtf_cols = [
    "chr", "source", "feature", "start", "end", 
    "score", "strand", "frame", "attributes"
]
gtf = pd.read_csv(
    GTF_FILE,
    sep="\t",
    comment="#",
    header=None,
    names=gtf_cols
)

gtf_genes = gtf[gtf["feature"] == "gene"].copy()

def parse_attr(attrs, key):
    for part in attrs.split(";"):
        part = part.strip()
        if not part:
            continue
        if part.startswith(key + " "):
            val = part.split(" ", 1)[1].strip().strip('"')
            return val
    return None

gtf_genes["gene_name"] = gtf_genes["attributes"].apply(
    lambda x: parse_attr(x, "gene_name")
)

# %%
gtf_core = gtf_genes[gtf_genes["gene_name"].isin(core_genes)].copy()
print(f"Найдено генов из ядра в GTF: {gtf_core['gene_name'].nunique()}")
# Out:
# Найдено генов из ядра в GTF: 1676

# %%
def tss_row(row):
    if row["strand"] == "+":
        return row["start"]
    else:
        return row["end"]

gtf_core["tss"] = gtf_core.apply(tss_row, axis=1)

# %%
bed_rows = []
for _, r in tqdm(gtf_core.iterrows()):
    tss = int(r["tss"])
    # GTF: 1-based, BED: 0-based half-open
    start = max(0, tss - 1 - WINDOW)
    end = tss - 1 + WINDOW + 1   # = tss + WINDOW
    bed_rows.append({
        "chr": r["chr"],
        "start": start,
        "end": end,
        "name": r["gene_name"],
        "strand": r["strand"],
    })

bed = pd.DataFrame(bed_rows)
bed.sort_values(["chr", "start", "end"], inplace=True)

bed.to_csv(OUT_BED, sep="\t", header=False, index=False)
print(f"Промоторные окна TSS±{WINDOW} сохранены в {OUT_BED}")
# Out:
# 1680it [00:00, 12367.67it/s]
# Промоторные окна TSS±1000 сохранены в ../../Datasets_old/PBMC10k_PBMC/output/celltypist/core_genes_regions_1000bp.bed

# %%
bed.head()
# Out:
#     chr    start      end      name strand
# 0  chr1   999171  1001172      HES4      -
# 1  chr1  1000137  1002138     ISG15      +
# 2  chr1  1172879  1174880    TTLL10      +
# 3  chr1  1205591  1207592  TNFRSF18      -
# 4  chr1  1420768  1422769   ANKRD65      -
